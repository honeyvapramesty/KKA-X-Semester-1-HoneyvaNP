# %% [markdown]
# <a href="https://colab.research.google.com/github/honeyvapramesty/KKA-X-Semester-1-HoneyvaNP/blob/main/3_Aplikasi_Sederhana_Honeyva_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi panjang

# %%
print("halo anwar")
# Out:
# halo anwar

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm):"))
lebar =int(input("Masukkan lebar dari persegi panjang (cm):"))

luas = panjang *lebar

print(f"\nLuas dari persegi panjangnya adalah {luas} cm^2.")
# Out:
# Masukkan panjang dari persegi panjang (cm):5
# Masukkan lebar dari persegi panjang (cm):4
#
# Luas dari persegi panjangnya adalah 20 cm^2.

# %% [markdown]
# #Nama kelompok:Burok keren
#
#
# Nama: Honeyva Neelam
#
#
# Kelas:X-1
#
#
# Nomor absen:13

# %%
Tinggi =int(input("Masukkan tinggi dari tabung (cm): "))
Jarijari =int(input("Masukkan jarijari dari tabung (cm): "))
Phi = 22/7

Volume = Phi * Jarijari**2*Tinggi

print(f"\nVolume dari tabung tersebut adalah {Volume} cm^3.")
# Out:
# Masukkan tinggi dari tabung (cm): 14
# Masukkan jarijari dari tabung (cm): 7
#
# Volume dari tabung tersebut adalah 2156.0 cm^3.
